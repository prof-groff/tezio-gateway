# %%
from pynput.keyboard import Key, Listener
print('hello world')
from IPython.display import clear_output

def on_key_release(key):
    if key == Key.up:
        clear_output(wait=True)
        print('up pressed')
    if key == Key.down:
        clear_output(wait=True)
        print('down pressed')
    if key == Key.right:
        clear_output(wait=True)
        print('right pressed')
    if key == Key.left:
        clear_output(wait=True)
        print('left pressed')
    if key == Key.esc:
        clear_output(wait=True)
        print('escape')
        return False

with Listener(on_release = on_key_release) as listener:
    listener.join()
# Out:
# escape

# %%
bip39Vocab = ["abandon", "ability", "able", "about", "above", "absent", "absorb", "abstract", "absurd", "abuse", "access", "accident", "account", "accuse", "achieve", 
                                "acid", "acoustic", "acquire", "across", "act", "action", "actor", "actress", "actual", "adapt", "add", "addict", "address", "adjust", "admit", "adult", 
                                "advance", "advice", "aerobic", "affair", "afford", "afraid", "again", "age", "agent", "agree", "ahead", "aim", "air", "airport", "aisle", "alarm", 
                                "album", "alcohol", "alert", "alien", "all", "alley", "allow", "almost", "alone", "alpha", "already", "also", "alter", "always", "amateur", "amazing", 
                                "among", "amount", "amused", "analyst", "anchor", "ancient", "anger", "angle", "angry", "animal", "ankle", "announce", "annual", "another", "answer", 
                                "antenna", "antique", "anxiety", "any", "apart", "apology", "appear", "apple", "approve", "april", "arch", "arctic", "area", "arena", "argue", "arm", 
                                "armed", "armor", "army", "around", "arrange", "arrest", "arrive", "arrow", "art", "artefact", "artist", "artwork", "ask", "aspect", "assault", "asset", 
                                "assist", "assume", "asthma", "athlete", "atom", "attack", "attend", "attitude", "attract", "auction", "audit", "august", "aunt", "author", "auto", 
                                "autumn", "average", "avocado", "avoid", "awake", "aware", "away", "awesome", "awful", "awkward", "axis", "baby", "bachelor", "bacon", "badge", "bag", 
                                "balance", "balcony", "ball", "bamboo", "banana", "banner", "bar", "barely", "bargain", "barrel", "base", "basic", "basket", "battle", "beach", "bean", 
                                "beauty", "because", "become", "beef", "before", "begin", "behave", "behind", "believe", "below", "belt", "bench", "benefit", "best", "betray", "better", 
                                "between", "beyond", "bicycle", "bid", "bike", "bind", "biology", "bird", "birth", "bitter", "black", "blade", "blame", "blanket", "blast", "bleak", 
                                "bless", "blind", "blood", "blossom", "blouse", "blue", "blur", "blush", "board", "boat", "body", "boil", "bomb", "bone", "bonus", "book", "boost", 
                                "border", "boring", "borrow", "boss", "bottom", "bounce", "box", "boy", "bracket", "brain", "brand", "brass", "brave", "bread", "breeze", "brick", 
                                "bridge", "brief", "bright", "bring", "brisk", "broccoli", "broken", "bronze", "broom", "brother", "brown", "brush", "bubble", "buddy", "budget", 
                                "buffalo", "build", "bulb", "bulk", "bullet", "bundle", "bunker", "burden", "burger", "burst", "bus", "business", "busy", "butter", "buyer", "buzz", 
                                "cabbage", "cabin", "cable", "cactus", "cage", "cake", "call", "calm", "camera", "camp", "can", "canal", "cancel", "candy", "cannon", "canoe", "canvas", 
                                "canyon", "capable", "capital", "captain", "car", "carbon", "card", "cargo", "carpet", "carry", "cart", "case", "cash", "casino", "castle", "casual", 
                                "pill", "pilot", "pink", "pioneer", "pipe", "pistol", "pitch", "pizza", "place", "planet", "plastic", "plate", "play", "please", "pledge", "pluck", "plug", 
                                "plunge", "poem", "poet", "point", "polar", "pole", "police", "pond", "pony", "pool", "popular", "portion", "position", "possible", "post", "potato", 
                                "pottery", "poverty", "powder", "power", "practice", "praise", "predict", "prefer", "prepare", "present", "pretty", "prevent", "price", "pride", "primary", 
                                "print", "priority", "prison", "private", "prize", "problem", "process", "produce", "profit", "program", "project", "promote", "proof", "property", 
                                "prosper", "protect", "proud", "provide", "public", "pudding", "pull", "pulp", "pulse", "pumpkin", "punch", "pupil", "puppy", "purchase", "purity", 
                                "purpose", "purse", "push", "put", "puzzle", "pyramid", "quality", "quantum", "quarter", "question", "quick", "quit", "quiz", "quote", "rabbit", "raccoon", 
                                "race", "rack", "radar", "radio", "rail", "rain", "raise", "rally", "ramp", "ranch", "random", "range", "rapid", "rare", "rate", "rather", "raven", "raw", 
                                "razor", "ready", "real", "reason", "rebel", "rebuild", "recall", "receive", "recipe", "record", "recycle", "reduce", "reflect", "reform", "refuse", 
                                "region", "regret", "regular", "reject", "relax", "release", "relief", "rely", "remain", "remember", "remind", "remove", "render", "renew", "rent", 
                                "reopen", "repair", "repeat", "replace", "report", "require", "rescue", "resemble", "resist", "resource", "response", "result", "retire", "retreat", 
                                "return", "reunion", "reveal", "review", "reward", "rhythm", "rib", "ribbon", "rice", "rich", "ride", "ridge", "rifle", "right", "rigid", "ring", "riot", 
                                "ripple", "risk", "ritual", "rival", "river", "road", "roast", "robot", "robust", "rocket", "romance", "roof", "rookie", "room", "rose", "rotate", "rough", 
                                "round", "route", "royal", "rubber", "rude", "rug", "rule", "run", "runway", "rural", "sad", "saddle", "sadness", "safe", "sail", "salad", "salmon", 
                                "salon", "salt", "salute", "same", "sample", "sand", "satisfy", "satoshi", "sauce", "sausage", "save", "say", "scale", "scan", "scare", "scatter", "scene", 
                                "scheme", "school", "science", "scissors", "scorpion", "scout", "scrap", "screen", "script", "scrub", "sea", "search", "season", "seat", "second", 
                                "secret", "section", "security", "seed", "seek", "segment", "select", "sell", "seminar", "senior", "sense", "sentence", "series", "service", "session", 
                                "settle", "setup", "seven", "shadow", "shaft", "shallow", "share", "shed", "shell", "sheriff", "shield", "shift", "shine", "ship", "shiver", "shock", 
                                "shoe", "shoot", "shop", "short", "shoulder", "shove", "shrimp", "shrug", "shuffle", "shy", "sibling", "sick", "side", "siege", "sight", "sign", "silent", 
                                "silk", "silly", "silver", "similar", "simple", "since", "sing", "siren", "sister", "situate", "six", "size", "skate", "sketch", "ski", "skill", "skin", 
                                "skirt", "skull", "slab", "slam", "sleep", "slender", "slice", "slide", "slight", "slim", "slogan", "slot", "slow", "slush", "small", "smart", "smile", 
                                "smoke", "smooth", "snack", "snake", "snap", "sniff", "snow", "soap", "soccer", "social", "sock", "soda", "soft", "solar", "soldier", "solid", "solution", 
                                "whale", "what", "wheat", "wheel", "when", "where", "whip", "whisper", "wide", "width", "wife", "wild", "will", "win", "window", "wine", "wing", "wink", 
                                "winner", "winter", "wire", "wisdom", "wise", "wish", "witness", "wolf", "woman", "wonder", "wood", "wool", "word", "work", "world", "worry", "worth", 
                                "wrap", "wreck", "wrestle", "wrist", "write", "wrong", "yard", "year", "yellow", "you", "young", "youth", "zebra", "zero", "zone", "zoo"]

# %%
import json

# Specify the file name
file_name = "bip39Vocab.json"

# Write the dictionary to a JSON file
with open(file_name, "w") as f:
    json.dump(bip39Vocab, f, indent=4)  # indent for pretty formatting

# %% [raw]
# # sort the vocab into a tree structure - THIS APPROACH HAD ISSUES
# vocabTree = {}
# for index, word in enumerate(bip39Vocab):
#     if len(word) == 3:
#         keys = [word[0], word[1], word[2], '*']
#     else:
#         keys = [word[0], word[1], word[2], word[3]]
#
#     if keys[0] in vocabTree.keys():
#         pass
#     else:
#         vocabTree[keys[0]] = {}
#     if keys[1] in vocabTree[keys[0]].keys():
#         pass
#     else:
#         vocabTree[keys[0]][keys[1]] = {}
#     if keys[2] in vocabTree[keys[0]][keys[1]].keys():
#         pass
#     else:
#         vocabTree[keys[0]][keys[1]][keys[2]] = {}
#
#     vocabTree[keys[0]][keys[1]][keys[2]][keys[3]] = [word, index]

# %% [raw]
# for l1 in list(vocabTree.keys()):
#     l1SubTree = vocabTree[l1]
#     if isinstance(l1SubTree, dict) and len(l1SubTree.keys()) > 1: # subtree is a dict and there is more than one key
#         for l2 in list(l1SubTree.keys()):
#             l2SubTree = l1SubTree[l2]
#             if isinstance(l2SubTree, dict) and len(l2SubTree.keys()) > 1:
#                 for l3 in list(l2Subtree.keys()):
#                     l3SubTree = l2SubTree[l3]
#                     if isinstance(l3SubTree, dict) and len(l3SubTree.keys()) > 1:
#                         pass # no collapsing necessary
#                     else: # collapse the fourth level
#                         l3
#                         vocabTree[l3]

# %% [raw]
# def uniqueSubstring(ii, vocab, ssLen):
#     noMatch = True
#     subStr = vocab[ii][:ssLen]
#     for jj, comp in enumerate(vocab):
#         if ii == jj:
#             pass # don't compare substring with itself
#         else:
#             if subStr == comp[:ssLen]: # match found
#                 noMatch = False
#                 break
#     return noMatch
#
# def nCharsUnique(ii, bip39Vocab):
#     nChars = 0
#     while True:
#         nChars += 1
#         if uniqueSubstring(ii, bip39Vocab, nChars):
#             break
#         else:
#             pass # do nothing
#     return nChars

# %% [raw]
# # lets try building the tree one word at a time - THIS APPROACH WAS A SUCCESS
# vocabTree = {}
#
# for ii, word in enumerate(bip39Vocab):
#     level = nCharsUnique(ii, bip39Vocab) # should be between 1 and 4, probably always 3 or 4
#     # print(word, level)
#     for jj in range(0,level-1):
#         curChar = word[jj]
#         if jj == 0:
#             try:
#                 vocabTree[curChar]
#             except:
#                 vocabTree[curChar] = {}
#         if jj == 1:
#             try:
#                 vocabTree[word[0]][curChar]
#             except:
#                 vocabTree[word[0]][curChar] = {}
#         if jj == 2:
#             try:
#                 vocabTree[word[0]][word[1]][curChar]
#             except:
#                 vocabTree[word[0]][word[1]][curChar] = {}
#         if jj == 3:
#             try:
#                 vocabTree[word[0]][word[1]][word[2]][curChar]
#             except:
#                 vocabTree[word[0]][word[1]][word[2]][curChar] = {}
#         if jj == 4 and len(word) == 3:
#             try:
#                 vocabTree[word[0]][word[1]][word[2]][word[3]]['*']
#             except:
#                 vocabTree[word[0]][word[1]][word[2]][word[3]]['*'] = {}
#     if level == 1:
#         vocabTree[word[0]] = [word, ii]
#     if level == 2:
#         vocabTree[word[0]][word[1]] = [word, ii]
#     if level == 3:
#         vocabTree[word[0]][word[1]][word[2]] = [word, ii]
#     if level == 4 and len(word) == 3:
#         vocabTree[word[0]][word[1]][word[2]]['*'] = [word, ii]
#     elif level == 4:
#         vocabTree[word[0]][word[1]][word[2]][word[3]] = [word, ii]

# %%
x = {'a': 'hi', 'b': {'c': 'hi', 'd': 'hi'}}
x
# Out:
# {'a': 'hi', 'b': {'c': 'hi', 'd': 'hi'}}

# %%
from pprint import pprint

# %% [raw]
# import json
#
# # Specify the file name
# file_name = "bip39VocabTree.json"
#
# # Write the dictionary to a JSON file
# with open(file_name, "w") as f:
#     json.dump(vocabTree, f, indent=4)  # indent for pretty formatting

# %%
import json

# Open the JSON file
with open('bip39VocabTree.json') as f:
    # Load the JSON data into a Python dictionary
    bip39VocabTree = json.load(f)

# Now you can work with the data dictionary
pprint(bip39VocabTree)
# Out:
# {'a': {'b': {'a': ['abandon', 0],
#              'i': ['ability', 1],
#              'l': ['able', 2],
#              'o': {'u': ['about', 3], 'v': ['above', 4]},
#              's': {'e': ['absent', 5],
#                    'o': ['absorb', 6],
#                    't': ['abstract', 7],
#                    'u': ['absurd', 8]},
#              'u': ['abuse', 9]},
#        'c': {'c': {'e': ['access', 10],
#                    'i': ['accident', 11],
#                    'o': ['account', 12],
#                    'u': ['accuse', 13]},
#              'h': ['achieve', 14],
#              'i': ['acid', 15],
#              'o': ['acoustic', 16],
#              'q': ['acquire', 17],
#              'r': ['across', 18],
#              't': {'*': ['act', 19],
#                    'i': ['action', 20],
#                    'o': ['actor', 21],
#                    'r': ['actress', 22],
#                    'u': ['actual', 23]}},
#        'd': {'a': ['adapt', 24],
#              'd': {'*': ['add', 25], 'i': ['addict', 26], 'r': ['address', 27]},
#              'j': ['adjust', 28],
#              'm': ['admit', 29],
#              'u': ['adult', 30],
#              'v': {'a': ['advance', 31], 'i': ['advice', 32]}},
#        'e': ['aerobic', 33],
#        'f': {'f': {'a': ['affair', 34], 'o': ['afford', 35]},
#              'r': ['afraid', 36]},
#        'g': {'a': ['again', 37],
#              'e': {'*': ['age', 38], 'n': ['agent', 39]},
#              'r': ['agree', 40]},
#        'h': ['ahead', 41],
#        'i': {'m': ['aim', 42],
#              'r': {'*': ['air', 43], 'p': ['airport', 44]},
#              's': ['aisle', 45]},
#        'l': {'a': ['alarm', 46],
#              'b': ['album', 47],
#              'c': ['alcohol', 48],
#              'e': ['alert', 49],
#              'i': ['alien', 50],
#              'l': {'*': ['all', 51], 'e': ['alley', 52], 'o': ['allow', 53]},
#              'm': ['almost', 54],
#              'o': ['alone', 55],
#              'p': ['alpha', 56],
#              'r': ['already', 57],
#              's': ['also', 58],
#              't': ['alter', 59],
#              'w': ['always', 60]},
#        'm': {'a': {'t': ['amateur', 61], 'z': ['amazing', 62]},
#              'o': {'n': ['among', 63], 'u': ['amount', 64]},
#              'u': ['amused', 65]},
#        'n': {'a': ['analyst', 66],
#              'c': {'h': ['anchor', 67], 'i': ['ancient', 68]},
#              'g': {'e': ['anger', 69], 'l': ['angle', 70], 'r': ['angry', 71]},
#              'i': ['animal', 72],
#              'k': ['ankle', 73],
#              'n': {'o': ['announce', 74], 'u': ['annual', 75]},
#              'o': ['another', 76],
#              's': ['answer', 77],
#              't': {'e': ['antenna', 78], 'i': ['antique', 79]},
#              'x': ['anxiety', 80],
#              'y': ['any', 81]},
#        'p': {'a': ['apart', 82],
#              'o': ['apology', 83],
#              'p': {'e': ['appear', 84],
#                    'l': ['apple', 85],
#                    'r': ['approve', 86]},
#              'r': ['april', 87]},
#        'r': {'c': {'h': ['arch', 88], 't': ['arctic', 89]},
#              'e': {'a': ['area', 90], 'n': ['arena', 91]},
#              'g': ['argue', 92],
#              'm': {'*': ['arm', 93],
#                    'e': ['armed', 94],
#                    'o': ['armor', 95],
#                    'y': ['army', 96]},
#              'o': ['around', 97],
#              'r': {'a': ['arrange', 98],
#                    'e': ['arrest', 99],
#                    'i': ['arrive', 100],
#                    'o': ['arrow', 101]},
#              't': {'*': ['art', 102],
#                    'e': ['artefact', 103],
#                    'i': ['artist', 104],
#                    'w': ['artwork', 105]}},
#        's': {'k': ['ask', 106],
#              'p': ['aspect', 107],
#              's': {'a': ['assault', 108],
#                    'e': ['asset', 109],
#                    'i': ['assist', 110],
#                    'u': ['assume', 111]},
#              't': ['asthma', 112]},
#        't': {'h': ['athlete', 113],
#              'o': ['atom', 114],
#              't': {'a': ['attack', 115],
#                    'e': ['attend', 116],
#                    'i': ['attitude', 117],
#                    'r': ['attract', 118]}},
#        'u': {'c': ['auction', 119],
#              'd': ['audit', 120],
#              'g': ['august', 121],
#              'n': ['aunt', 122],
#              't': {'h': ['author', 123],
#                    'o': ['auto', 124],
#                    'u': ['autumn', 125]}},
#        'v': {'e': ['average', 126],
#              'o': {'c': ['avocado', 127], 'i': ['avoid', 128]}},
#        'w': {'a': {'k': ['awake', 129],
#                    'r': ['aware', 130],
#                    'y': ['away', 131]},
#              'e': ['awesome', 132],
#              'f': ['awful', 133],
#              'k': ['awkward', 134]},
#        'x': ['axis', 135]},
#  'b': {'a': {'b': ['baby', 136],
#              'c': {'h': ['bachelor', 137], 'o': ['bacon', 138]},
#              'd': ['badge', 139],
#              'g': ['bag', 140],
#              'l': {'a': ['balance', 141],
#                    'c': ['balcony', 142],
#                    'l': ['ball', 143]},
#              'm': ['bamboo', 144],
#              'n': {'a': ['banana', 145], 'n': ['banner', 146]},
#              'r': {'*': ['bar', 147],
#                    'e': ['barely', 148],
#                    'g': ['bargain', 149],
#                    'r': ['barrel', 150]},
#              's': {'e': ['base', 151],
#                    'i': ['basic', 152],
#                    'k': ['basket', 153]},
#              't': ['battle', 154]},
#        'e': {'a': {'c': ['beach', 155],
#                    'n': ['bean', 156],
#                    'u': ['beauty', 157]},
#              'c': {'a': ['because', 158], 'o': ['become', 159]},
#              'e': ['beef', 160],
#              'f': ['before', 161],
#              'g': ['begin', 162],
#              'h': {'a': ['behave', 163], 'i': ['behind', 164]},
#              'l': {'i': ['believe', 165],
#                    'o': ['below', 166],
#                    't': ['belt', 167]},
#              'n': {'c': ['bench', 168], 'e': ['benefit', 169]},
#              's': ['best', 170],
#              't': {'r': ['betray', 171],
#                    't': ['better', 172],
#                    'w': ['between', 173]},
#              'y': ['beyond', 174]},
#        'i': {'c': ['bicycle', 175],
#              'd': ['bid', 176],
#              'k': ['bike', 177],
#              'n': ['bind', 178],
#              'o': ['biology', 179],
#              'r': {'d': ['bird', 180], 't': ['birth', 181]},
#              't': ['bitter', 182]},
#        'l': {'a': {'c': ['black', 183],
#                    'd': ['blade', 184],
#                    'm': ['blame', 185],
#                    'n': ['blanket', 186],
#                    's': ['blast', 187]},
#              'e': {'a': ['bleak', 188], 's': ['bless', 189]},
#              'i': ['blind', 190],
#              'o': {'o': ['blood', 191],
#                    's': ['blossom', 192],
#                    'u': ['blouse', 193]},
#              'u': {'e': ['blue', 194],
#                    'r': ['blur', 195],
#                    's': ['blush', 196]}},
#        'o': {'a': {'r': ['board', 197], 't': ['boat', 198]},
#              'd': ['body', 199],
#              'i': ['boil', 200],
#              'm': ['bomb', 201],
#              'n': {'e': ['bone', 202], 'u': ['bonus', 203]},
#              'o': {'k': ['book', 204], 's': ['boost', 205]},
#              'r': {'d': ['border', 206],
#                    'i': ['boring', 207],
#                    'r': ['borrow', 208]},
#              's': ['boss', 209],
#              't': ['bottom', 210],
#              'u': ['bounce', 211],
#              'x': ['box', 212],
#              'y': ['boy', 213]},
#        'r': {'a': {'c': ['bracket', 214],
#                    'i': ['brain', 215],
#                    'n': ['brand', 216],
#                    's': ['brass', 217],
#                    'v': ['brave', 218]},
#              'e': {'a': ['bread', 219], 'e': ['breeze', 220]},
#              'i': {'c': ['brick', 221],
#                    'd': ['bridge', 222],
#                    'e': ['brief', 223],
#                    'g': ['bright', 224],
#                    'n': ['bring', 225],
#                    's': ['brisk', 226]},
#              'o': {'c': ['broccoli', 227],
#                    'k': ['broken', 228],
#                    'n': ['bronze', 229],
#                    'o': ['broom', 230],
#                    't': ['brother', 231],
#                    'w': ['brown', 232]},
#              'u': ['brush', 233]},
#        'u': {'b': ['bubble', 234],
#              'd': {'d': ['buddy', 235], 'g': ['budget', 236]},
#              'f': ['buffalo', 237],
#              'i': ['build', 238],
#              'l': {'b': ['bulb', 239],
#                    'k': ['bulk', 240],
#                    'l': ['bullet', 241]},
#              'n': {'d': ['bundle', 242], 'k': ['bunker', 243]},
#              'r': {'d': ['burden', 244],
#                    'g': ['burger', 245],
#                    's': ['burst', 246]},
#              's': {'*': ['bus', 247],
#                    'i': ['business', 248],
#                    'y': ['busy', 249]},
#              't': ['butter', 250],
#              'y': ['buyer', 251],
#              'z': ['buzz', 252]}},
#  'c': {'a': {'b': {'b': ['cabbage', 253],
#                    'i': ['cabin', 254],
#                    'l': ['cable', 255]},
#              'c': ['cactus', 256],
#              'g': ['cage', 257],
#              'k': ['cake', 258],
#              'l': {'l': ['call', 259], 'm': ['calm', 260]},
#              'm': {'e': ['camera', 261], 'p': ['camp', 262]},
#              'n': {'*': ['can', 263],
#                    'a': ['canal', 264],
#                    'c': ['cancel', 265],
#                    'd': ['candy', 266],
#                    'n': ['cannon', 267],
#                    'o': ['canoe', 268],
#                    'v': ['canvas', 269],
#                    'y': ['canyon', 270]},
#              'p': {'a': ['capable', 271],
#                    'i': ['capital', 272],
#                    't': ['captain', 273]},
#              'r': {'*': ['car', 274],
#                    'b': ['carbon', 275],
#                    'd': ['card', 276],
#                    'g': ['cargo', 277],
#                    'p': ['carpet', 278],
#                    'r': ['carry', 279],
#                    't': ['cart', 280]},
#              's': {'e': ['case', 281],
#                    'h': ['cash', 282],
#                    'i': ['casino', 283],
#                    't': ['castle', 284],
#                    'u': ['casual', 285]},
#              't': {'*': ['cat', 286],
#                    'a': ['catalog', 287],
#                    'c': ['catch', 288],
#                    'e': ['category', 289],
#                    't': ['cattle', 290]},
#              'u': {'g': ['caught', 291],
#                    's': ['cause', 292],
#                    't': ['caution', 293]},
#              'v': ['cave', 294]},
#        'e': {'i': ['ceiling', 295],
#              'l': ['celery', 296],
#              'm': ['cement', 297],
#              'n': {'s': ['census', 298], 't': ['century', 299]},
#              'r': {'e': ['cereal', 300], 't': ['certain', 301]}},
#        'h': {'a': {'i': ['chair', 302],
#                    'l': ['chalk', 303],
#                    'm': ['champion', 304],
#                    'n': ['change', 305],
#                    'o': ['chaos', 306],
#                    'p': ['chapter', 307],
#                    'r': ['charge', 308],
#                    's': ['chase', 309],
#                    't': ['chat', 310]},
#              'e': {'a': ['cheap', 311],
#                    'c': ['check', 312],
#                    'e': ['cheese', 313],
#                    'f': ['chef', 314],
#                    'r': ['cherry', 315],
#                    's': ['chest', 316]},
#              'i': {'c': ['chicken', 317],
#                    'e': ['chief', 318],
#                    'l': ['child', 319],
#                    'm': ['chimney', 320]},
#              'o': {'i': ['choice', 321], 'o': ['choose', 322]},
#              'r': ['chronic', 323],
#              'u': {'c': ['chuckle', 324],
#                    'n': ['chunk', 325],
#                    'r': ['churn', 326]}},
#        'i': {'g': ['cigar', 327],
#              'n': ['cinnamon', 328],
#              'r': ['circle', 329],
#              't': {'i': ['citizen', 330], 'y': ['city', 331]},
#              'v': ['civil', 332]},
#        'l': {'a': {'i': ['claim', 333],
#                    'p': ['clap', 334],
#                    'r': ['clarify', 335],
#                    'w': ['claw', 336],
#                    'y': ['clay', 337]},
#              'e': {'a': ['clean', 338],
#                    'r': ['clerk', 339],
#                    'v': ['clever', 340]},
#              'i': {'c': ['click', 341],
#                    'e': ['client', 342],
#                    'f': ['cliff', 343],
#                    'm': ['climb', 344],
#                    'n': ['clinic', 345],
#                    'p': ['clip', 346]},
#              'o': {'c': ['clock', 347],
#                    'g': ['clog', 348],
#                    's': ['close', 349],
#                    't': ['cloth', 350],
#                    'u': ['cloud', 351],
#                    'w': ['clown', 352]},
#              'u': {'b': ['club', 353],
#                    'm': ['clump', 354],
#                    's': ['cluster', 355],
#                    't': ['clutch', 356]}},
#        'o': {'a': {'c': ['coach', 357], 's': ['coast', 358]},
#              'c': ['coconut', 359],
#              'd': ['code', 360],
#              'f': ['coffee', 361],
#              'i': {'l': ['coil', 362], 'n': ['coin', 363]},
#              'l': {'l': ['collect', 364],
#                    'o': ['color', 365],
#                    'u': ['column', 366]},
#              'm': {'b': ['combine', 367],
#                    'e': ['come', 368],
#                    'f': ['comfort', 369],
#                    'i': ['comic', 370],
#                    'm': ['common', 371],
#                    'p': ['company', 372]},
#              'n': {'c': ['concert', 373],
#                    'd': ['conduct', 374],
#                    'f': ['confirm', 375],
#                    'g': ['congress', 376],
#                    'n': ['connect', 377],
#                    's': ['consider', 378],
#                    't': ['control', 379],
#                    'v': ['convince', 380]},
#              'o': {'k': ['cook', 381], 'l': ['cool', 382]},
#              'p': {'p': ['copper', 383], 'y': ['copy', 384]},
#              'r': {'a': ['coral', 385],
#                    'e': ['core', 386],
#                    'n': ['corn', 387],
#                    'r': ['correct', 388]},
#              's': ['cost', 389],
#              't': ['cotton', 390],
#              'u': {'c': ['couch', 391],
#                    'n': ['country', 392],
#                    'p': ['couple', 393],
#                    'r': ['course', 394],
#                    's': ['cousin', 395]},
#              'v': ['cover', 396],
#              'y': ['coyote', 397]},
#        'r': {'a': {'c': ['crack', 398],
#                    'd': ['cradle', 399],
#                    'f': ['craft', 400],
#                    'm': ['cram', 401],
#                    'n': ['crane', 402],
#                    's': ['crash', 403],
#                    't': ['crater', 404],
#                    'w': ['crawl', 405],
#                    'z': ['crazy', 406]},
#              'e': {'a': ['cream', 407],
#                    'd': ['credit', 408],
#                    'e': ['creek', 409],
#                    'w': ['crew', 410]},
#              'i': {'c': ['cricket', 411],
#                    'm': ['crime', 412],
#                    's': ['crisp', 413],
#                    't': ['critic', 414]},
#              'o': {'p': ['crop', 415],
#                    's': ['cross', 416],
#                    'u': ['crouch', 417],
#                    'w': ['crowd', 418]},
#              'u': {'c': ['crucial', 419],
#                    'e': ['cruel', 420],
#                    'i': ['cruise', 421],
#                    'm': ['crumble', 422],
#                    'n': ['crunch', 423],
#                    's': ['crush', 424]},
#              'y': {'*': ['cry', 425], 's': ['crystal', 426]}},
#        'u': {'b': ['cube', 427],
#              'l': ['culture', 428],
#              'p': {'*': ['cup', 429], 'b': ['cupboard', 430]},
#              'r': {'i': ['curious', 431],
#                    'r': ['current', 432],
#                    't': ['curtain', 433],
#                    'v': ['curve', 434]},
#              's': {'h': ['cushion', 435], 't': ['custom', 436]},
#              't': ['cute', 437]},
#        'y': ['cycle', 438]},
#  'd': {'a': {'d': ['dad', 439],
#              'm': {'a': ['damage', 440], 'p': ['damp', 441]},
#              'n': {'c': ['dance', 442], 'g': ['danger', 443]},
#              'r': ['daring', 444],
#              's': ['dash', 445],
#              'u': ['daughter', 446],
#              'w': ['dawn', 447],
#              'y': ['day', 448]},
#        'e': {'a': ['deal', 449],
#              'b': {'a': ['debate', 450], 'r': ['debris', 451]},
#              'c': {'a': ['decade', 452],
#                    'e': ['december', 453],
#                    'i': ['decide', 454],
#                    'l': ['decline', 455],
#                    'o': ['decorate', 456],
#                    'r': ['decrease', 457]},
#              'e': ['deer', 458],
#              'f': {'e': ['defense', 459],
#                    'i': ['define', 460],
#                    'y': ['defy', 461]},
#              'g': ['degree', 462],
#              'l': {'a': ['delay', 463], 'i': ['deliver', 464]},
#              'm': {'a': ['demand', 465], 'i': ['demise', 466]},
#              'n': {'i': ['denial', 467],
#                    't': ['dentist', 468],
#                    'y': ['deny', 469]},
#              'p': {'a': ['depart', 470],
#                    'e': ['depend', 471],
#                    'o': ['deposit', 472],
#                    't': ['depth', 473],
#                    'u': ['deputy', 474]},
#              'r': ['derive', 475],
#              's': {'c': ['describe', 476],
#                    'e': ['desert', 477],
#                    'i': ['design', 478],
#                    'k': ['desk', 479],
#                    'p': ['despair', 480],
#                    't': ['destroy', 481]},
#              't': {'a': ['detail', 482], 'e': ['detect', 483]},
#              'v': {'e': ['develop', 484],
#                    'i': ['device', 485],
#                    'o': ['devote', 486]}},
#        'i': {'a': {'g': ['diagram', 487],
#                    'l': ['dial', 488],
#                    'm': ['diamond', 489],
#                    'r': ['diary', 490]},
#              'c': ['dice', 491],
#              'e': {'s': ['diesel', 492], 't': ['diet', 493]},
#              'f': ['differ', 494],
#              'g': {'i': ['digital', 495], 'n': ['dignity', 496]},
#              'l': ['dilemma', 497],
#              'n': {'n': ['dinner', 498], 'o': ['dinosaur', 499]},
#              'r': {'e': ['direct', 500], 't': ['dirt', 501]},
#              's': {'a': ['disagree', 502],
#                    'c': ['discover', 503],
#                    'e': ['disease', 504],
#                    'h': ['dish', 505],
#                    'm': ['dismiss', 506],
#                    'o': ['disorder', 507],
#                    'p': ['display', 508],
#                    't': ['distance', 509]},
#              'v': {'e': ['divert', 510],
#                    'i': ['divide', 511],
#                    'o': ['divorce', 512]},
#              'z': ['dizzy', 513]},
#        'o': {'c': {'t': ['doctor', 514], 'u': ['document', 515]},
#              'g': ['dog', 516],
#              'l': {'l': ['doll', 517], 'p': ['dolphin', 518]},
#              'm': ['domain', 519],
#              'n': {'a': ['donate', 520],
#                    'k': ['donkey', 521],
#                    'o': ['donor', 522]},
#              'o': ['door', 523],
#              's': ['dose', 524],
#              'u': ['double', 525],
#              'v': ['dove', 526]},
#        'r': {'a': {'f': ['draft', 527],
#                    'g': ['dragon', 528],
#                    'm': ['drama', 529],
#                    's': ['drastic', 530],
#                    'w': ['draw', 531]},
#              'e': {'a': ['dream', 532], 's': ['dress', 533]},
#              'i': {'f': ['drift', 534],
#                    'l': ['drill', 535],
#                    'n': ['drink', 536],
#                    'p': ['drip', 537],
#                    'v': ['drive', 538]},
#              'o': ['drop', 539],
#              'u': ['drum', 540],
#              'y': ['dry', 541]},
#        'u': {'c': ['duck', 542],
#              'm': ['dumb', 543],
#              'n': ['dune', 544],
#              'r': ['during', 545],
#              's': ['dust', 546],
#              't': {'c': ['dutch', 547], 'y': ['duty', 548]}},
#        'w': ['dwarf', 549],
#        'y': ['dynamic', 550]},
#  'e': {'a': {'g': {'e': ['eager', 551], 'l': ['eagle', 552]},
#              'r': {'l': ['early', 553],
#                    'n': ['earn', 554],
#                    't': ['earth', 555]},
#              's': {'i': ['easily', 556],
#                    't': ['east', 557],
#                    'y': ['easy', 558]}},
#        'c': {'h': ['echo', 559],
#              'o': {'l': ['ecology', 560], 'n': ['economy', 561]}},
#        'd': {'g': ['edge', 562], 'i': ['edit', 563], 'u': ['educate', 564]},
#        'f': ['effort', 565],
#        'g': ['egg', 566],
#        'i': {'g': ['eight', 567], 't': ['either', 568]},
#        'l': {'b': ['elbow', 569],
#              'd': ['elder', 570],
#              'e': {'c': ['electric', 571],
#                    'g': ['elegant', 572],
#                    'm': ['element', 573],
#                    'p': ['elephant', 574],
#                    'v': ['elevator', 575]},
#              'i': ['elite', 576],
#              's': ['else', 577]},
#        'm': {'b': {'a': ['embark', 578],
#                    'o': ['embody', 579],
#                    'r': ['embrace', 580]},
#              'e': ['emerge', 581],
#              'o': ['emotion', 582],
#              'p': {'l': ['employ', 583],
#                    'o': ['empower', 584],
#                    't': ['empty', 585]}},
#        'n': {'a': {'b': ['enable', 586], 'c': ['enact', 587]},
#              'd': {'*': ['end', 588],
#                    'l': ['endless', 589],
#                    'o': ['endorse', 590]},
#              'e': {'m': ['enemy', 591], 'r': ['energy', 592]},
#              'f': ['enforce', 593],
#              'g': {'a': ['engage', 594], 'i': ['engine', 595]},
#              'h': ['enhance', 596],
#              'j': ['enjoy', 597],
#              'l': ['enlist', 598],
#              'o': ['enough', 599],
#              'r': {'i': ['enrich', 600], 'o': ['enroll', 601]},
#              's': ['ensure', 602],
#              't': {'e': ['enter', 603],
#                    'i': ['entire', 604],
#                    'r': ['entry', 605]},
#              'v': ['envelope', 606]},
#        'p': ['episode', 607],
#        'q': {'u': {'a': ['equal', 608], 'i': ['equip', 609]}},
#        'r': {'a': {'*': ['era', 610], 's': ['erase', 611]},
#              'o': {'d': ['erode', 612], 's': ['erosion', 613]},
#              'r': ['error', 614],
#              'u': ['erupt', 615]},
#        's': {'c': ['escape', 616],
#              's': {'a': ['essay', 617], 'e': ['essence', 618]},
#              't': ['estate', 619]},
#        't': {'e': ['eternal', 620], 'h': ['ethics', 621]},
#        'v': {'i': {'d': ['evidence', 622], 'l': ['evil', 623]},
#              'o': {'k': ['evoke', 624], 'l': ['evolve', 625]}},
#        'x': {'a': {'c': ['exact', 626], 'm': ['example', 627]},
#              'c': {'e': ['excess', 628],
#                    'h': ['exchange', 629],
#                    'i': ['excite', 630],
#                    'l': ['exclude', 631],
#                    'u': ['excuse', 632]},
#              'e': {'c': ['execute', 633], 'r': ['exercise', 634]},
#              'h': {'a': ['exhaust', 635], 'i': ['exhibit', 636]},
#              'i': {'l': ['exile', 637],
#                    's': ['exist', 638],
#                    't': ['exit', 639]},
#              'o': ['exotic', 640],
#              'p': {'a': ['expand', 641],
#                    'e': ['expect', 642],
#                    'i': ['expire', 643],
#                    'l': ['explain', 644],
#                    'o': ['expose', 645],
#                    'r': ['express', 646]},
#              't': {'e': ['extend', 647], 'r': ['extra', 648]}},
#        'y': {'e': {'*': ['eye', 649], 'b': ['eyebrow', 650]}}},
#  'f': {'a': {'b': ['fabric', 651],
#              'c': {'e': ['face', 652], 'u': ['faculty', 653]},
#              'd': ['fade', 654],
#              'i': {'n': ['faint', 655], 't': ['faith', 656]},
#              'l': {'l': ['fall', 657], 's': ['false', 658]},
#              'm': {'e': ['fame', 659],
#                    'i': ['family', 660],
#                    'o': ['famous', 661]},
#              'n': {'*': ['fan', 662],
#                    'c': ['fancy', 663],
#                    't': ['fantasy', 664]},
#              'r': ['farm', 665],
#              's': ['fashion', 666],
#              't': {'*': ['fat', 667],
#                    'a': ['fatal', 668],
#                    'h': ['father', 669],
#                    'i': ['fatigue', 670]},
#              'u': ['fault', 671],
#              'v': ['favorite', 672]},
#        'e': {'a': ['feature', 673],
#              'b': ['february', 674],
#              'd': ['federal', 675],
#              'e': {'*': ['fee', 676], 'd': ['feed', 677], 'l': ['feel', 678]},
#              'm': ['female', 679],
#              'n': ['fence', 680],
#              's': ['festival', 681],
#              't': ['fetch', 682],
#              'v': ['fever', 683],
#              'w': ['few', 684]},
#        'i': {'b': ['fiber', 685],
#              'c': ['fiction', 686],
#              'e': ['field', 687],
#              'g': ['figure', 688],
#              'l': {'e': ['file', 689],
#                    'm': ['film', 690],
#                    't': ['filter', 691]},
#              'n': {'a': ['final', 692],
#                    'd': ['find', 693],
#                    'e': ['fine', 694],
#                    'g': ['finger', 695],
#                    'i': ['finish', 696]},
#              'r': {'e': ['fire', 697], 'm': ['firm', 698], 's': ['first', 699]},
#              's': {'c': ['fiscal', 700], 'h': ['fish', 701]},
#              't': {'*': ['fit', 702], 'n': ['fitness', 703]},
#              'x': ['fix', 704]},
#        'l': {'a': {'g': ['flag', 705],
#                    'm': ['flame', 706],
#                    's': ['flash', 707],
#                    't': ['flat', 708],
#                    'v': ['flavor', 709]},
#              'e': ['flee', 710],
#              'i': {'g': ['flight', 711], 'p': ['flip', 712]},
#              'o': {'a': ['float', 713],
#                    'c': ['flock', 714],
#                    'o': ['floor', 715],
#                    'w': ['flower', 716]},
#              'u': {'i': ['fluid', 717], 's': ['flush', 718]},
#              'y': ['fly', 719]},
#        'o': {'a': ['foam', 720],
#              'c': ['focus', 721],
#              'g': ['fog', 722],
#              'i': ['foil', 723],
#              'l': {'d': ['fold', 724], 'l': ['follow', 725]},
#              'o': {'d': ['food', 726], 't': ['foot', 727]},
#              'r': {'c': ['force', 728],
#                    'e': ['forest', 729],
#                    'g': ['forget', 730],
#                    'k': ['fork', 731],
#                    't': ['fortune', 732],
#                    'u': ['forum', 733],
#                    'w': ['forward', 734]},
#              's': {'s': ['fossil', 735], 't': ['foster', 736]},
#              'u': ['found', 737],
#              'x': ['fox', 738]},
#        'r': {'a': {'g': ['fragile', 739], 'm': ['frame', 740]},
#              'e': {'q': ['frequent', 741], 's': ['fresh', 742]},
#              'i': {'e': ['friend', 743], 'n': ['fringe', 744]},
#              'o': {'g': ['frog', 745],
#                    'n': ['front', 746],
#                    's': ['frost', 747],
#                    'w': ['frown', 748],
#                    'z': ['frozen', 749]},
#              'u': ['fruit', 750]},
#        'u': {'e': ['fuel', 751],
#              'n': {'*': ['fun', 752], 'n': ['funny', 753]},
#              'r': {'n': ['furnace', 754], 'y': ['fury', 755]},
#              't': ['future', 756]}},
#  'g': {'a': {'d': ['gadget', 757],
#              'i': ['gain', 758],
#              'l': {'a': ['galaxy', 759], 'l': ['gallery', 760]},
#              'm': ['game', 761],
#              'p': ['gap', 762],
#              'r': {'a': ['garage', 763],
#                    'b': ['garbage', 764],
#                    'd': ['garden', 765],
#                    'l': ['garlic', 766],
#                    'm': ['garment', 767]},
#              's': {'*': ['gas', 768], 'p': ['gasp', 769]},
#              't': {'e': ['gate', 770], 'h': ['gather', 771]},
#              'u': ['gauge', 772],
#              'z': ['gaze', 773]},
#        'e': {'n': {'e': ['general', 774],
#                    'i': ['genius', 775],
#                    'r': ['genre', 776],
#                    't': ['gentle', 777],
#                    'u': ['genuine', 778]},
#              's': ['gesture', 779]},
#        'h': ['ghost', 780],
#        'i': {'a': ['giant', 781],
#              'f': ['gift', 782],
#              'g': ['giggle', 783],
#              'n': ['ginger', 784],
#              'r': {'a': ['giraffe', 785], 'l': ['girl', 786]},
#              'v': ['give', 787]},
#        'l': {'a': {'d': ['glad', 788],
#                    'n': ['glance', 789],
#                    'r': ['glare', 790],
#                    's': ['glass', 791]},
#              'i': {'d': ['glide', 792], 'm': ['glimpse', 793]},
#              'o': {'b': ['globe', 794],
#                    'o': ['gloom', 795],
#                    'r': ['glory', 796],
#                    'v': ['glove', 797],
#                    'w': ['glow', 798]},
#              'u': ['glue', 799]},
#        'o': {'a': ['goat', 800],
#              'd': ['goddess', 801],
#              'l': ['gold', 802],
#              'o': {'d': ['good', 803], 's': ['goose', 804]},
#              'r': ['gorilla', 805],
#              's': {'p': ['gospel', 806], 's': ['gossip', 807]},
#              'v': ['govern', 808],
#              'w': ['gown', 809]},
#        'r': {'a': {'b': ['grab', 810],
#                    'c': ['grace', 811],
#                    'i': ['grain', 812],
#                    'n': ['grant', 813],
#                    'p': ['grape', 814],
#                    's': ['grass', 815],
#                    'v': ['gravity', 816]},
#              'e': {'a': ['great', 817], 'e': ['green', 818]},
#              'i': {'d': ['grid', 819], 'e': ['grief', 820], 't': ['grit', 821]},
#              'o': {'c': ['grocery', 822],
#                    'u': ['group', 823],
#                    'w': ['grow', 824]},
#              'u': ['grunt', 825]},
#        'u': {'a': ['guard', 826],
#              'e': ['guess', 827],
#              'i': {'d': ['guide', 828],
#                    'l': ['guilt', 829],
#                    't': ['guitar', 830]},
#              'n': ['gun', 831]},
#        'y': ['gym', 832]},
#  'h': {'a': {'b': ['habit', 833],
#              'i': ['hair', 834],
#              'l': ['half', 835],
#              'm': {'m': ['hammer', 836], 's': ['hamster', 837]},
#              'n': ['hand', 838],
#              'p': ['happy', 839],
#              'r': {'b': ['harbor', 840],
#                    'd': ['hard', 841],
#                    's': ['harsh', 842],
#                    'v': ['harvest', 843]},
#              't': ['hat', 844],
#              'v': ['have', 845],
#              'w': ['hawk', 846],
#              'z': ['hazard', 847]},
#        'e': {'a': {'d': ['head', 848],
#                    'l': ['health', 849],
#                    'r': ['heart', 850],
#                    'v': ['heavy', 851]},
#              'd': ['hedgehog', 852],
#              'i': ['height', 853],
#              'l': {'l': ['hello', 854],
#                    'm': ['helmet', 855],
#                    'p': ['help', 856]},
#              'n': ['hen', 857],
#              'r': ['hero', 858]},
#        'i': {'d': ['hidden', 859],
#              'g': ['high', 860],
#              'l': ['hill', 861],
#              'n': ['hint', 862],
#              'p': ['hip', 863],
#              'r': ['hire', 864],
#              's': ['history', 865]},
#        'o': {'b': ['hobby', 866],
#              'c': ['hockey', 867],
#              'l': {'d': ['hold', 868],
#                    'e': ['hole', 869],
#                    'i': ['holiday', 870],
#                    'l': ['hollow', 871]},
#              'm': ['home', 872],
#              'n': ['honey', 873],
#              'o': ['hood', 874],
#              'p': ['hope', 875],
#              'r': {'n': ['horn', 876],
#                    'r': ['horror', 877],
#                    's': ['horse', 878]},
#              's': {'p': ['hospital', 879], 't': ['host', 880]},
#              't': ['hotel', 881],
#              'u': ['hour', 882],
#              'v': ['hover', 883]},
#        'u': {'b': ['hub', 884],
#              'g': ['huge', 885],
#              'm': {'a': ['human', 886],
#                    'b': ['humble', 887],
#                    'o': ['humor', 888]},
#              'n': {'d': ['hundred', 889],
#                    'g': ['hungry', 890],
#                    't': ['hunt', 891]},
#              'r': {'d': ['hurdle', 892],
#                    'r': ['hurry', 893],
#                    't': ['hurt', 894]},
#              's': ['husband', 895]},
#        'y': ['hybrid', 896]},
#  'i': {'c': {'e': ['ice', 897], 'o': ['icon', 898]},
#        'd': {'e': {'a': ['idea', 899], 'n': ['identify', 900]},
#              'l': ['idle', 901]},
#        'g': ['ignore', 902],
#        'l': {'l': {'*': ['ill', 903],
#                    'e': ['illegal', 904],
#                    'n': ['illness', 905]}},
#        'm': {'a': ['image', 906],
#              'i': ['imitate', 907],
#              'm': {'e': ['immense', 908], 'u': ['immune', 909]},
#              'p': {'a': ['impact', 910],
#                    'o': ['impose', 911],
#                    'r': ['improve', 912],
#                    'u': ['impulse', 913]}},
#        'n': {'c': {'h': ['inch', 914],
#                    'l': ['include', 915],
#                    'o': ['income', 916],
#                    'r': ['increase', 917]},
#              'd': {'e': ['index', 918],
#                    'i': ['indicate', 919],
#                    'o': ['indoor', 920],
#                    'u': ['industry', 921]},
#              'f': {'a': ['infant', 922],
#                    'l': ['inflict', 923],
#                    'o': ['inform', 924]},
#              'h': {'a': ['inhale', 925], 'e': ['inherit', 926]},
#              'i': ['initial', 927],
#              'j': {'e': ['inject', 928], 'u': ['injury', 929]},
#              'm': ['inmate', 930],
#              'n': {'e': ['inner', 931], 'o': ['innocent', 932]},
#              'p': ['input', 933],
#              'q': ['inquiry', 934],
#              's': {'a': ['insane', 935],
#                    'e': ['insect', 936],
#                    'i': ['inside', 937],
#                    'p': ['inspire', 938],
#                    't': ['install', 939]},
#              't': {'a': ['intact', 940],
#                    'e': ['interest', 941],
#                    'o': ['into', 942]},
#              'v': {'e': ['invest', 943],
#                    'i': ['invite', 944],
#                    'o': ['involve', 945]}},
#        'r': ['iron', 946],
#        's': {'l': ['island', 947], 'o': ['isolate', 948], 's': ['issue', 949]},
#        't': ['item', 950],
#        'v': ['ivory', 951]},
#  'j': {'a': {'c': ['jacket', 952],
#              'g': ['jaguar', 953],
#              'r': ['jar', 954],
#              'z': ['jazz', 955]},
#        'e': {'a': {'l': ['jealous', 956], 'n': ['jeans', 957]},
#              'l': ['jelly', 958],
#              'w': ['jewel', 959]},
#        'o': {'b': ['job', 960],
#              'i': ['join', 961],
#              'k': ['joke', 962],
#              'u': ['journey', 963],
#              'y': ['joy', 964]},
#        'u': {'d': ['judge', 965],
#              'i': ['juice', 966],
#              'm': ['jump', 967],
#              'n': {'g': ['jungle', 968],
#                    'i': ['junior', 969],
#                    'k': ['junk', 970]},
#              's': ['just', 971]}},
#  'k': {'a': ['kangaroo', 972],
#        'e': {'e': {'n': ['keen', 973], 'p': ['keep', 974]},
#              't': ['ketchup', 975],
#              'y': ['key', 976]},
#        'i': {'c': ['kick', 977],
#              'd': {'*': ['kid', 978], 'n': ['kidney', 979]},
#              'n': {'d': ['kind', 980], 'g': ['kingdom', 981]},
#              's': ['kiss', 982],
#              't': {'*': ['kit', 983],
#                    'c': ['kitchen', 984],
#                    'e': ['kite', 985],
#                    't': ['kitten', 986]},
#              'w': ['kiwi', 987]},
#        'n': {'e': ['knee', 988],
#              'i': ['knife', 989],
#              'o': {'c': ['knock', 990], 'w': ['know', 991]}}},
#  'l': {'a': {'b': {'*': ['lab', 992], 'e': ['label', 993], 'o': ['labor', 994]},
#              'd': {'d': ['ladder', 995], 'y': ['lady', 996]},
#              'k': ['lake', 997],
#              'm': ['lamp', 998],
#              'n': ['language', 999],
#              'p': ['laptop', 1000],
#              'r': ['large', 1001],
#              't': {'e': ['later', 1002], 'i': ['latin', 1003]},
#              'u': {'g': ['laugh', 1004], 'n': ['laundry', 1005]},
#              'v': ['lava', 1006],
#              'w': {'*': ['law', 1007],
#                    'n': ['lawn', 1008],
#                    's': ['lawsuit', 1009]},
#              'y': ['layer', 1010],
#              'z': ['lazy', 1011]},
#        'e': {'a': {'d': ['leader', 1012],
#                    'f': ['leaf', 1013],
#                    'r': ['learn', 1014],
#                    'v': ['leave', 1015]},
#              'c': ['lecture', 1016],
#              'f': ['left', 1017],
#              'g': {'*': ['leg', 1018],
#                    'a': ['legal', 1019],
#                    'e': ['legend', 1020]},
#              'i': ['leisure', 1021],
#              'm': ['lemon', 1022],
#              'n': {'d': ['lend', 1023],
#                    'g': ['length', 1024],
#                    's': ['lens', 1025]},
#              'o': ['leopard', 1026],
#              's': ['lesson', 1027],
#              't': ['letter', 1028],
#              'v': ['level', 1029]},
#        'i': {'a': ['liar', 1030],
#              'b': {'e': ['liberty', 1031], 'r': ['library', 1032]},
#              'c': ['license', 1033],
#              'f': {'e': ['life', 1034], 't': ['lift', 1035]},
#              'g': ['light', 1036],
#              'k': ['like', 1037],
#              'm': {'b': ['limb', 1038], 'i': ['limit', 1039]},
#              'n': ['link', 1040],
#              'o': ['lion', 1041],
#              'q': ['liquid', 1042],
#              's': ['list', 1043],
#              't': ['little', 1044],
#              'v': ['live', 1045],
#              'z': ['lizard', 1046]},
#        'o': {'a': {'d': ['load', 1047], 'n': ['loan', 1048]},
#              'b': ['lobster', 1049],
#              'c': {'a': ['local', 1050], 'k': ['lock', 1051]},
#              'g': ['logic', 1052],
#              'n': {'e': ['lonely', 1053], 'g': ['long', 1054]},
#              'o': ['loop', 1055],
#              't': ['lottery', 1056],
#              'u': {'d': ['loud', 1057], 'n': ['lounge', 1058]},
#              'v': ['love', 1059],
#              'y': ['loyal', 1060]},
#        'u': {'c': ['lucky', 1061],
#              'g': ['luggage', 1062],
#              'm': ['lumber', 1063],
#              'n': {'a': ['lunar', 1064], 'c': ['lunch', 1065]},
#              'x': ['luxury', 1066]},
#        'y': ['lyrics', 1067]},
#  'm': {'a': {'c': ['machine', 1068],
#              'd': ['mad', 1069],
#              'g': {'i': ['magic', 1070], 'n': ['magnet', 1071]},
#              'i': {'d': ['maid', 1072],
#                    'l': ['mail', 1073],
#                    'n': ['main', 1074]},
#              'j': ['major', 1075],
#              'k': ['make', 1076],
#              'm': ['mammal', 1077],
#              'n': {'*': ['man', 1078],
#                    'a': ['manage', 1079],
#                    'd': ['mandate', 1080],
#                    'g': ['mango', 1081],
#                    's': ['mansion', 1082],
#                    'u': ['manual', 1083]},
#              'p': ['maple', 1084],
#              'r': {'b': ['marble', 1085],
#                    'c': ['march', 1086],
#                    'g': ['margin', 1087],
#                    'i': ['marine', 1088],
#                    'k': ['market', 1089],
#                    'r': ['marriage', 1090]},
#              's': {'k': ['mask', 1091],
#                    's': ['mass', 1092],
#                    't': ['master', 1093]},
#              't': {'c': ['match', 1094],
#                    'e': ['material', 1095],
#                    'h': ['math', 1096],
#                    'r': ['matrix', 1097],
#                    't': ['matter', 1098]},
#              'x': ['maximum', 1099],
#              'z': ['maze', 1100]},
#        'e': {'a': {'d': ['meadow', 1101],
#                    'n': ['mean', 1102],
#                    's': ['measure', 1103],
#                    't': ['meat', 1104]},
#              'c': ['mechanic', 1105],
#              'd': {'a': ['medal', 1106], 'i': ['media', 1107]},
#              'l': {'o': ['melody', 1108], 't': ['melt', 1109]},
#              'm': {'b': ['member', 1110], 'o': ['memory', 1111]},
#              'n': {'t': ['mention', 1112], 'u': ['menu', 1113]},
#              'r': {'c': ['mercy', 1114],
#                    'g': ['merge', 1115],
#                    'i': ['merit', 1116],
#                    'r': ['merry', 1117]},
#              's': {'h': ['mesh', 1118], 's': ['message', 1119]},
#              't': {'a': ['metal', 1120], 'h': ['method', 1121]}},
#        'i': {'d': {'d': ['middle', 1122], 'n': ['midnight', 1123]},
#              'l': {'k': ['milk', 1124], 'l': ['million', 1125]},
#              'm': ['mimic', 1126],
#              'n': {'d': ['mind', 1127],
#                    'i': ['minimum', 1128],
#                    'o': ['minor', 1129],
#                    'u': ['minute', 1130]},
#              'r': {'a': ['miracle', 1131], 'r': ['mirror', 1132]},
#              's': {'e': ['misery', 1133],
#                    's': ['miss', 1134],
#                    't': ['mistake', 1135]},
#              'x': {'*': ['mix', 1136],
#                    'e': ['mixed', 1137],
#                    't': ['mixture', 1138]}},
#        'o': {'b': ['mobile', 1139],
#              'd': {'e': ['model', 1140], 'i': ['modify', 1141]},
#              'm': {'*': ['mom', 1142], 'e': ['moment', 1143]},
#              'n': {'i': ['monitor', 1144],
#                    'k': ['monkey', 1145],
#                    's': ['monster', 1146],
#                    't': ['month', 1147]},
#              'o': ['moon', 1148],
#              'r': {'a': ['moral', 1149],
#                    'e': ['more', 1150],
#                    'n': ['morning', 1151]},
#              's': ['mosquito', 1152],
#              't': {'h': ['mother', 1153],
#                    'i': ['motion', 1154],
#                    'o': ['motor', 1155]},
#              'u': {'n': ['mountain', 1156], 's': ['mouse', 1157]},
#              'v': {'e': ['move', 1158], 'i': ['movie', 1159]}},
#        'u': {'c': ['much', 1160],
#              'f': ['muffin', 1161],
#              'l': {'e': ['mule', 1162], 't': ['multiply', 1163]},
#              's': {'c': ['muscle', 1164],
#                    'e': ['museum', 1165],
#                    'h': ['mushroom', 1166],
#                    'i': ['music', 1167],
#                    't': ['must', 1168]},
#              't': ['mutual', 1169]},
#        'y': {'s': {'e': ['myself', 1170], 't': ['mystery', 1171]},
#              't': ['myth', 1172]}},
#  'n': {'a': {'i': ['naive', 1173],
#              'm': ['name', 1174],
#              'p': ['napkin', 1175],
#              'r': ['narrow', 1176],
#              's': ['nasty', 1177],
#              't': {'i': ['nation', 1178], 'u': ['nature', 1179]}},
#        'e': {'a': ['near', 1180],
#              'c': ['neck', 1181],
#              'e': ['need', 1182],
#              'g': {'a': ['negative', 1183], 'l': ['neglect', 1184]},
#              'i': ['neither', 1185],
#              'p': ['nephew', 1186],
#              'r': ['nerve', 1187],
#              's': ['nest', 1188],
#              't': {'*': ['net', 1189], 'w': ['network', 1190]},
#              'u': ['neutral', 1191],
#              'v': ['never', 1192],
#              'w': ['news', 1193],
#              'x': ['next', 1194]},
#        'i': {'c': ['nice', 1195], 'g': ['night', 1196]},
#        'o': {'b': ['noble', 1197],
#              'i': ['noise', 1198],
#              'm': ['nominee', 1199],
#              'o': ['noodle', 1200],
#              'r': {'m': ['normal', 1201], 't': ['north', 1202]},
#              's': ['nose', 1203],
#              't': {'a': ['notable', 1204],
#                    'e': ['note', 1205],
#                    'h': ['nothing', 1206],
#                    'i': ['notice', 1207]},
#              'v': ['novel', 1208],
#              'w': ['now', 1209]},
#        'u': {'c': ['nuclear', 1210],
#              'm': ['number', 1211],
#              'r': ['nurse', 1212],
#              't': ['nut', 1213]}},
#  'o': {'a': ['oak', 1214],
#        'b': {'e': ['obey', 1215],
#              'j': ['object', 1216],
#              'l': ['oblige', 1217],
#              's': {'c': ['obscure', 1218], 'e': ['observe', 1219]},
#              't': ['obtain', 1220],
#              'v': ['obvious', 1221]},
#        'c': {'c': ['occur', 1222],
#              'e': ['ocean', 1223],
#              't': ['october', 1224]},
#        'd': ['odor', 1225],
#        'f': {'f': {'*': ['off', 1226],
#                    'e': ['offer', 1227],
#                    'i': ['office', 1228]},
#              't': ['often', 1229]},
#        'i': ['oil', 1230],
#        'k': ['okay', 1231],
#        'l': {'d': ['old', 1232], 'i': ['olive', 1233], 'y': ['olympic', 1234]},
#        'm': ['omit', 1235],
#        'n': {'c': ['once', 1236],
#              'e': ['one', 1237],
#              'i': ['onion', 1238],
#              'l': {'i': ['online', 1239], 'y': ['only', 1240]}},
#        'p': {'e': {'n': ['open', 1241], 'r': ['opera', 1242]},
#              'i': ['opinion', 1243],
#              'p': ['oppose', 1244],
#              't': ['option', 1245]},
#        'r': {'a': ['orange', 1246],
#              'b': ['orbit', 1247],
#              'c': ['orchard', 1248],
#              'd': {'e': ['order', 1249], 'i': ['ordinary', 1250]},
#              'g': ['organ', 1251],
#              'i': {'e': ['orient', 1252], 'g': ['original', 1253]},
#              'p': ['orphan', 1254]},
#        's': ['ostrich', 1255],
#        't': ['other', 1256],
#        'u': {'t': {'d': ['outdoor', 1257],
#                    'e': ['outer', 1258],
#                    'p': ['output', 1259],
#                    's': ['outside', 1260]}},
#        'v': {'a': ['oval', 1261],
#              'e': {'n': ['oven', 1262], 'r': ['over', 1263]}},
#        'w': {'n': {'*': ['own', 1264], 'e': ['owner', 1265]}},
#        'x': ['oxygen', 1266],
#        'y': ['oyster', 1267],
#        'z': ['ozone', 1268]},
#  'p': {'a': {'c': ['pact', 1269],
#              'd': ['paddle', 1270],
#              'g': ['page', 1271],
#              'i': ['pair', 1272],
#              'l': {'a': ['palace', 1273], 'm': ['palm', 1274]},
#              'n': {'d': ['panda', 1275],
#                    'e': ['panel', 1276],
#                    'i': ['panic', 1277],
#                    't': ['panther', 1278]},
#              'p': ['paper', 1279],
#              'r': {'a': ['parade', 1280],
#                    'e': ['parent', 1281],
#                    'k': ['park', 1282],
#                    'r': ['parrot', 1283],
#                    't': ['party', 1284]},
#              's': ['pass', 1285],
#              't': {'c': ['patch', 1286],
#                    'h': ['path', 1287],
#                    'i': ['patient', 1288],
#                    'r': ['patrol', 1289],
#                    't': ['pattern', 1290]},
#              'u': ['pause', 1291],
#              'v': ['pave', 1292],
#              'y': ['payment', 1293]},
#        'e': {'a': {'c': ['peace', 1294],
#                    'n': ['peanut', 1295],
#                    'r': ['pear', 1296],
#                    's': ['peasant', 1297]},
#              'l': ['pelican', 1298],
#              'n': {'*': ['pen', 1299],
#                    'a': ['penalty', 1300],
#                    'c': ['pencil', 1301]},
#              'o': ['people', 1302],
#              'p': ['pepper', 1303],
#              'r': {'f': ['perfect', 1304],
#                    'm': ['permit', 1305],
#                    's': ['person', 1306]},
#              't': ['pet', 1307]},
#        'h': {'o': {'n': ['phone', 1308], 't': ['photo', 1309]},
#              'r': ['phrase', 1310],
#              'y': ['physical', 1311]},
#        'i': {'a': ['piano', 1312],
#              'c': {'n': ['picnic', 1313], 't': ['picture', 1314]},
#              'e': ['piece', 1315],
#              'g': {'*': ['pig', 1316], 'e': ['pigeon', 1317]},
#              'l': {'l': ['pill', 1318], 'o': ['pilot', 1319]},
# ...
#              'e': {'e': ['sleep', 1625], 'n': ['slender', 1626]},
#              'i': {'c': ['slice', 1627],
#                    'd': ['slide', 1628],
#                    'g': ['slight', 1629],
#                    'm': ['slim', 1630]},
#              'o': {'g': ['slogan', 1631],
#                    't': ['slot', 1632],
#                    'w': ['slow', 1633]},
#              'u': ['slush', 1634]},
#        'm': {'a': {'l': ['small', 1635], 'r': ['smart', 1636]},
#              'i': ['smile', 1637],
#              'o': {'k': ['smoke', 1638], 'o': ['smooth', 1639]}},
#        'n': {'a': {'c': ['snack', 1640],
#                    'k': ['snake', 1641],
#                    'p': ['snap', 1642]},
#              'i': ['sniff', 1643],
#              'o': ['snow', 1644]},
#        'o': {'a': ['soap', 1645],
#              'c': {'c': ['soccer', 1646],
#                    'i': ['social', 1647],
#                    'k': ['sock', 1648]},
#              'd': ['soda', 1649],
#              'f': ['soft', 1650],
#              'l': {'a': ['solar', 1651],
#                    'd': ['soldier', 1652],
#                    'i': ['solid', 1653],
#                    'u': ['solution', 1654],
#                    'v': ['solve', 1655]},
#              'm': ['someone', 1656],
#              'n': ['song', 1657],
#              'o': ['soon', 1658],
#              'r': {'r': ['sorry', 1659], 't': ['sort', 1660]},
#              'u': {'l': ['soul', 1661],
#                    'n': ['sound', 1662],
#                    'p': ['soup', 1663],
#                    'r': ['source', 1664],
#                    't': ['south', 1665]}},
#        'p': {'a': {'c': ['space', 1666],
#                    'r': ['spare', 1667],
#                    't': ['spatial', 1668],
#                    'w': ['spawn', 1669]},
#              'e': {'a': ['speak', 1670],
#                    'c': ['special', 1671],
#                    'e': ['speed', 1672],
#                    'l': ['spell', 1673],
#                    'n': ['spend', 1674]},
#              'h': ['sphere', 1675],
#              'i': {'c': ['spice', 1676],
#                    'd': ['spider', 1677],
#                    'k': ['spike', 1678],
#                    'n': ['spin', 1679],
#                    'r': ['spirit', 1680]},
#              'l': ['split', 1681],
#              'o': {'i': ['spoil', 1682],
#                    'n': ['sponsor', 1683],
#                    'o': ['spoon', 1684],
#                    'r': ['sport', 1685],
#                    't': ['spot', 1686]},
#              'r': {'a': ['spray', 1687],
#                    'e': ['spread', 1688],
#                    'i': ['spring', 1689]},
#              'y': ['spy', 1690]},
#        'q': {'u': {'a': ['square', 1691],
#                    'e': ['squeeze', 1692],
#                    'i': ['squirrel', 1693]}},
#        't': {'a': {'b': ['stable', 1694],
#                    'd': ['stadium', 1695],
#                    'f': ['staff', 1696],
#                    'g': ['stage', 1697],
#                    'i': ['stairs', 1698],
#                    'm': ['stamp', 1699],
#                    'n': ['stand', 1700],
#                    'r': ['start', 1701],
#                    't': ['state', 1702],
#                    'y': ['stay', 1703]},
#              'e': {'a': ['steak', 1704],
#                    'e': ['steel', 1705],
#                    'm': ['stem', 1706],
#                    'p': ['step', 1707],
#                    'r': ['stereo', 1708]},
#              'i': {'c': ['stick', 1709],
#                    'l': ['still', 1710],
#                    'n': ['sting', 1711]},
#              'o': {'c': ['stock', 1712],
#                    'm': ['stomach', 1713],
#                    'n': ['stone', 1714],
#                    'o': ['stool', 1715],
#                    'r': ['story', 1716],
#                    'v': ['stove', 1717]},
#              'r': {'a': ['strategy', 1718],
#                    'e': ['street', 1719],
#                    'i': ['strike', 1720],
#                    'o': ['strong', 1721],
#                    'u': ['struggle', 1722]},
#              'u': {'d': ['student', 1723],
#                    'f': ['stuff', 1724],
#                    'm': ['stumble', 1725]},
#              'y': ['style', 1726]},
#        'u': {'b': {'j': ['subject', 1727],
#                    'm': ['submit', 1728],
#                    'w': ['subway', 1729]},
#              'c': {'c': ['success', 1730], 'h': ['such', 1731]},
#              'd': ['sudden', 1732],
#              'f': ['suffer', 1733],
#              'g': {'a': ['sugar', 1734], 'g': ['suggest', 1735]},
#              'i': ['suit', 1736],
#              'm': ['summer', 1737],
#              'n': {'*': ['sun', 1738],
#                    'n': ['sunny', 1739],
#                    's': ['sunset', 1740]},
#              'p': {'e': ['super', 1741],
#                    'p': ['supply', 1742],
#                    'r': ['supreme', 1743]},
#              'r': {'e': ['sure', 1744],
#                    'f': ['surface', 1745],
#                    'g': ['surge', 1746],
#                    'p': ['surprise', 1747],
#                    'r': ['surround', 1748],
#                    'v': ['survey', 1749]},
#              's': {'p': ['suspect', 1750], 't': ['sustain', 1751]}},
#        'w': {'a': {'l': ['swallow', 1752],
#                    'm': ['swamp', 1753],
#                    'p': ['swap', 1754],
#                    'r': ['swarm', 1755]},
#              'e': {'a': ['swear', 1756], 'e': ['sweet', 1757]},
#              'i': {'f': ['swift', 1758],
#                    'm': ['swim', 1759],
#                    'n': ['swing', 1760],
#                    't': ['switch', 1761]},
#              'o': ['sword', 1762]},
#        'y': {'m': {'b': ['symbol', 1763], 'p': ['symptom', 1764]},
#              'r': ['syrup', 1765],
#              's': ['system', 1766]}},
#  't': {'a': {'b': ['table', 1767],
#              'c': ['tackle', 1768],
#              'g': ['tag', 1769],
#              'i': ['tail', 1770],
#              'l': {'e': ['talent', 1771], 'k': ['talk', 1772]},
#              'n': ['tank', 1773],
#              'p': ['tape', 1774],
#              'r': ['target', 1775],
#              's': {'k': ['task', 1776], 't': ['taste', 1777]},
#              't': ['tattoo', 1778],
#              'x': ['taxi', 1779]},
#        'e': {'a': {'c': ['teach', 1780], 'm': ['team', 1781]},
#              'l': ['tell', 1782],
#              'n': {'*': ['ten', 1783],
#                    'a': ['tenant', 1784],
#                    'n': ['tennis', 1785],
#                    't': ['tent', 1786]},
#              'r': ['term', 1787],
#              's': ['test', 1788],
#              'x': ['text', 1789]},
#        'h': {'a': {'n': ['thank', 1790], 't': ['that', 1791]},
#              'e': {'m': ['theme', 1792],
#                    'n': ['then', 1793],
#                    'o': ['theory', 1794],
#                    'r': ['there', 1795],
#                    'y': ['they', 1796]},
#              'i': {'n': ['thing', 1797], 's': ['this', 1798]},
#              'o': ['thought', 1799],
#              'r': {'e': ['three', 1800],
#                    'i': ['thrive', 1801],
#                    'o': ['throw', 1802]},
#              'u': {'m': ['thumb', 1803], 'n': ['thunder', 1804]}},
#        'i': {'c': ['ticket', 1805],
#              'd': ['tide', 1806],
#              'g': ['tiger', 1807],
#              'l': ['tilt', 1808],
#              'm': {'b': ['timber', 1809], 'e': ['time', 1810]},
#              'n': ['tiny', 1811],
#              'p': ['tip', 1812],
#              'r': ['tired', 1813],
#              's': ['tissue', 1814],
#              't': ['title', 1815]},
#        'o': {'a': ['toast', 1816],
#              'b': ['tobacco', 1817],
#              'd': {'a': ['today', 1818], 'd': ['toddler', 1819]},
#              'e': ['toe', 1820],
#              'g': ['together', 1821],
#              'i': ['toilet', 1822],
#              'k': ['token', 1823],
#              'm': {'a': ['tomato', 1824], 'o': ['tomorrow', 1825]},
#              'n': {'e': ['tone', 1826],
#                    'g': ['tongue', 1827],
#                    'i': ['tonight', 1828]},
#              'o': {'l': ['tool', 1829], 't': ['tooth', 1830]},
#              'p': {'*': ['top', 1831],
#                    'i': ['topic', 1832],
#                    'p': ['topple', 1833]},
#              'r': {'c': ['torch', 1834],
#                    'n': ['tornado', 1835],
#                    't': ['tortoise', 1836]},
#              's': ['toss', 1837],
#              't': ['total', 1838],
#              'u': ['tourist', 1839],
#              'w': {'a': ['toward', 1840],
#                    'e': ['tower', 1841],
#                    'n': ['town', 1842]},
#              'y': ['toy', 1843]},
#        'r': {'a': {'c': ['track', 1844],
#                    'd': ['trade', 1845],
#                    'f': ['traffic', 1846],
#                    'g': ['tragic', 1847],
#                    'i': ['train', 1848],
#                    'n': ['transfer', 1849],
#                    'p': ['trap', 1850],
#                    's': ['trash', 1851],
#                    'v': ['travel', 1852],
#                    'y': ['tray', 1853]},
#              'e': {'a': ['treat', 1854],
#                    'e': ['tree', 1855],
#                    'n': ['trend', 1856]},
#              'i': {'a': ['trial', 1857],
#                    'b': ['tribe', 1858],
#                    'c': ['trick', 1859],
#                    'g': ['trigger', 1860],
#                    'm': ['trim', 1861],
#                    'p': ['trip', 1862]},
#              'o': {'p': ['trophy', 1863], 'u': ['trouble', 1864]},
#              'u': {'c': ['truck', 1865],
#                    'e': ['true', 1866],
#                    'l': ['truly', 1867],
#                    'm': ['trumpet', 1868],
#                    's': ['trust', 1869],
#                    't': ['truth', 1870]},
#              'y': ['try', 1871]},
#        'u': {'b': ['tube', 1872],
#              'i': ['tuition', 1873],
#              'm': ['tumble', 1874],
#              'n': {'a': ['tuna', 1875], 'n': ['tunnel', 1876]},
#              'r': {'k': ['turkey', 1877],
#                    'n': ['turn', 1878],
#                    't': ['turtle', 1879]}},
#        'w': {'e': {'l': ['twelve', 1880], 'n': ['twenty', 1881]},
#              'i': {'c': ['twice', 1882],
#                    'n': ['twin', 1883],
#                    's': ['twist', 1884]},
#              'o': ['two', 1885]},
#        'y': {'p': {'e': ['type', 1886], 'i': ['typical', 1887]}}},
#  'u': {'g': ['ugly', 1888],
#        'm': ['umbrella', 1889],
#        'n': {'a': {'b': ['unable', 1890], 'w': ['unaware', 1891]},
#              'c': {'l': ['uncle', 1892], 'o': ['uncover', 1893]},
#              'd': {'e': ['under', 1894], 'o': ['undo', 1895]},
#              'f': {'a': ['unfair', 1896], 'o': ['unfold', 1897]},
#              'h': ['unhappy', 1898],
#              'i': {'f': ['uniform', 1899],
#                    'q': ['unique', 1900],
#                    't': ['unit', 1901],
#                    'v': ['universe', 1902]},
#              'k': ['unknown', 1903],
#              'l': ['unlock', 1904],
#              't': ['until', 1905],
#              'u': ['unusual', 1906],
#              'v': ['unveil', 1907]},
#        'p': {'d': ['update', 1908],
#              'g': ['upgrade', 1909],
#              'h': ['uphold', 1910],
#              'o': ['upon', 1911],
#              'p': ['upper', 1912],
#              's': ['upset', 1913]},
#        'r': {'b': ['urban', 1914], 'g': ['urge', 1915]},
#        's': {'a': ['usage', 1916],
#              'e': {'*': ['use', 1917],
#                    'd': ['used', 1918],
#                    'f': ['useful', 1919],
#                    'l': ['useless', 1920]},
#              'u': ['usual', 1921]},
#        't': ['utility', 1922]},
#  'v': {'a': {'c': {'a': ['vacant', 1923], 'u': ['vacuum', 1924]},
#              'g': ['vague', 1925],
#              'l': {'i': ['valid', 1926],
#                    'l': ['valley', 1927],
#                    'v': ['valve', 1928]},
#              'n': {'*': ['van', 1929], 'i': ['vanish', 1930]},
#              'p': ['vapor', 1931],
#              'r': ['various', 1932],
#              's': ['vast', 1933],
#              'u': ['vault', 1934]},
#        'e': {'h': ['vehicle', 1935],
#              'l': ['velvet', 1936],
#              'n': {'d': ['vendor', 1937],
#                    't': ['venture', 1938],
#                    'u': ['venue', 1939]},
#              'r': {'b': ['verb', 1940],
#                    'i': ['verify', 1941],
#                    's': ['version', 1942],
#                    'y': ['very', 1943]},
#              's': ['vessel', 1944],
#              't': ['veteran', 1945]},
#        'i': {'a': ['viable', 1946],
#              'b': ['vibrant', 1947],
#              'c': {'i': ['vicious', 1948], 't': ['victory', 1949]},
#              'd': ['video', 1950],
#              'e': ['view', 1951],
#              'l': ['village', 1952],
#              'n': ['vintage', 1953],
#              'o': ['violin', 1954],
#              'r': {'t': ['virtual', 1955], 'u': ['virus', 1956]},
#              's': {'a': ['visa', 1957],
#                    'i': ['visit', 1958],
#                    'u': ['visual', 1959]},
#              't': ['vital', 1960],
#              'v': ['vivid', 1961]},
#        'o': {'c': ['vocal', 1962],
#              'i': {'c': ['voice', 1963], 'd': ['void', 1964]},
#              'l': {'c': ['volcano', 1965], 'u': ['volume', 1966]},
#              't': ['vote', 1967],
#              'y': ['voyage', 1968]}},
#  'w': {'a': {'g': {'e': ['wage', 1969], 'o': ['wagon', 1970]},
#              'i': ['wait', 1971],
#              'l': {'k': ['walk', 1972],
#                    'l': ['wall', 1973],
#                    'n': ['walnut', 1974]},
#              'n': ['want', 1975],
#              'r': {'f': ['warfare', 1976],
#                    'm': ['warm', 1977],
#                    'r': ['warrior', 1978]},
#              's': {'h': ['wash', 1979],
#                    'p': ['wasp', 1980],
#                    't': ['waste', 1981]},
#              't': ['water', 1982],
#              'v': ['wave', 1983],
#              'y': ['way', 1984]},
#        'e': {'a': {'l': ['wealth', 1985],
#                    'p': ['weapon', 1986],
#                    'r': ['wear', 1987],
#                    's': ['weasel', 1988],
#                    't': ['weather', 1989]},
#              'b': ['web', 1990],
#              'd': ['wedding', 1991],
#              'e': ['weekend', 1992],
#              'i': ['weird', 1993],
#              'l': ['welcome', 1994],
#              's': ['west', 1995],
#              't': ['wet', 1996]},
#        'h': {'a': {'l': ['whale', 1997], 't': ['what', 1998]},
#              'e': {'a': ['wheat', 1999],
#                    'e': ['wheel', 2000],
#                    'n': ['when', 2001],
#                    'r': ['where', 2002]},
#              'i': {'p': ['whip', 2003], 's': ['whisper', 2004]}},
#        'i': {'d': {'e': ['wide', 2005], 't': ['width', 2006]},
#              'f': ['wife', 2007],
#              'l': {'d': ['wild', 2008], 'l': ['will', 2009]},
#              'n': {'*': ['win', 2010],
#                    'd': ['window', 2011],
#                    'e': ['wine', 2012],
#                    'g': ['wing', 2013],
#                    'k': ['wink', 2014],
#                    'n': ['winner', 2015],
#                    't': ['winter', 2016]},
#              'r': ['wire', 2017],
#              's': {'d': ['wisdom', 2018],
#                    'e': ['wise', 2019],
#                    'h': ['wish', 2020]},
#              't': ['witness', 2021]},
#        'o': {'l': ['wolf', 2022],
#              'm': ['woman', 2023],
#              'n': ['wonder', 2024],
#              'o': {'d': ['wood', 2025], 'l': ['wool', 2026]},
#              'r': {'d': ['word', 2027],
#                    'k': ['work', 2028],
#                    'l': ['world', 2029],
#                    'r': ['worry', 2030],
#                    't': ['worth', 2031]}},
#        'r': {'a': ['wrap', 2032],
#              'e': {'c': ['wreck', 2033], 's': ['wrestle', 2034]},
#              'i': {'s': ['wrist', 2035], 't': ['write', 2036]},
#              'o': ['wrong', 2037]}},
#  'y': {'a': ['yard', 2038],
#        'e': {'a': ['year', 2039], 'l': ['yellow', 2040]},
#        'o': {'u': {'*': ['you', 2041],
#                    'n': ['young', 2042],
#                    't': ['youth', 2043]}}},
#  'z': {'e': {'b': ['zebra', 2044], 'r': ['zero', 2045]},
#        'o': {'n': ['zone', 2046], 'o': ['zoo', 2047]}}}

# %%
import random
def getRandomWord(currentWord, vocab):
    searching = True
    while searching:
        randomWord = random.choice(vocab)
        if randomWord == currentWord:
            pass # continue the search 
        else:
            searching = False
    return randomWord

def showWordChoice(currentWord, randomWord):
    
    
    choice = random.choice([['left', currentWord + ' ' + randomWord], ['right', randomWord + ' ' + currentWord]])
    
    
    print(choice)

# %%
currentWord = 'zoo'
randomWord = getRandomWord(currentWord, bip39Vocab)
showWordChoice(currentWord, randomWord)
# Out:
# ['left', 'zoo aim']

# %%
word = 'zoo'
average = 0
nHits = 0
triesSinceHit = 0
for each in range(0,100000000,1):
    triesSinceHit += 1
    if word == getRandomWord('zoo', bip39Vocab):
        if nHits == 0:
            average = triesSinceHit
            nHits += 1
        else:
            average = average*nHits+triesSinceHit
            nHits += 1
            average = average/nHits
        triesSinceHit = 0
        print(average, ': ', word, ': duplicate found')
    else:
        pass
# Out:
# 1992 :  zoo : duplicate found
# 1220.0 :  zoo : duplicate found
# 1058.0 :  zoo : duplicate found
# 1263.5 :  zoo : duplicate found
# 1233.8 :  zoo : duplicate found
# 1628.1666666666667 :  zoo : duplicate found
# 1523.142857142857 :  zoo : duplicate found
# 1499.0 :  zoo : duplicate found
# 1642.6666666666667 :  zoo : duplicate found
# 1548.6 :  zoo : duplicate found
# 1424.090909090909 :  zoo : duplicate found
# 1810.9166666666667 :  zoo : duplicate found
# 1695.7692307692307 :  zoo : duplicate found
# 1976.5714285714287 :  zoo : duplicate found
# 1874.4666666666667 :  zoo : duplicate found
# 1768.375 :  zoo : duplicate found
# 2140.470588235294 :  zoo : duplicate found
# 2156.1666666666665 :  zoo : duplicate found
# 2048.1052631578946 :  zoo : duplicate found
# 2024.4 :  zoo : duplicate found
# 2338.0 :  zoo : duplicate found
# 2409.318181818182 :  zoo : duplicate found
# 2620.8695652173915 :  zoo : duplicate found
# 2584.666666666667 :  zoo : duplicate found
# 2517.2400000000002 :  zoo : duplicate found
# 2533.153846153846 :  zoo : duplicate found
# 2470.5185185185187 :  zoo : duplicate found
# 2443.75 :  zoo : duplicate found
# 2475.4137931034484 :  zoo : duplicate found
# 2503.5 :  zoo : duplicate found
# 2457.3225806451615 :  zoo : duplicate found
# 2405.15625 :  zoo : duplicate found
# 2433.151515151515 :  zoo : duplicate found
# 2483.9411764705883 :  zoo : duplicate found
# 2420.5142857142855 :  zoo : duplicate found
# 2413.722222222222 :  zoo : duplicate found
# 2612.864864864865 :  zoo : duplicate found
# 2595.4736842105262 :  zoo : duplicate found
# 2580.2051282051284 :  zoo : duplicate found
# 2568.9500000000003 :  zoo : duplicate found
# 2583.707317073171 :  zoo : duplicate found
# 2557.5476190476193 :  zoo : duplicate found
# 2573.744186046512 :  zoo : duplicate found
# 2596.454545454546 :  zoo : duplicate found
# 2544.333333333334 :  zoo : duplicate found
# 2497.08695652174 :  zoo : duplicate found
# 2452.8085106382987 :  zoo : duplicate found
# 2422.4583333333344 :  zoo : duplicate found
# 2439.4897959183686 :  zoo : duplicate found
# 2419.300000000001 :  zoo : duplicate found
# 2378.9803921568637 :  zoo : duplicate found
# 2350.73076923077 :  zoo : duplicate found
# 2048.4286241163727 :  zoo : duplicate found
# 2048.503298774732 :  zoo : duplicate found
# 2048.560472882979 :  zoo : duplicate found
# 2048.5945336829936 :  zoo : duplicate found
# 2048.6480362228185 :  zoo : duplicate found
# 2048.7060028682554 :  zoo : duplicate found
# 2048.667595419056 :  zoo : duplicate found

# %%
# what needs to happen
# 1) Display a letter option at the end of all previously selected letters.
# If one of the letter options is *, display this. Otherwise display a random option from all valid options.
# If the current letter option results in a single unique word, display this word too.
# If the current letter option is selected, and this results in a word. Go to the confirm screen
# If the word is confirmed and there are more words that need to be selected, 
# save the word and index, clear previously selected letters and go back to #1
# If this word is the last one that is needed then END entry
# If the current letter option is slected and this does not result in a word, add it to the previously selected letters 
# return to step 1. 
import random

menomonic =[]
menomonicIndeces = []

def getSubTree(letterSelections, vocabTree):
    subTree = vocabTree
    for letter in letterSelections:
        subTree = subTree[letter]
    return subTree

# returns True, [Word, Index] if the current subTree is a vocab word
# returns False, {dictionary of options} if the current subTree still has multiple branches. 
def getLetterOptions(vocabSubTree):
    if isinstance(vocabSubTree, dict):
        return False, list(vocabSubTree.keys())
    else:
        return True, vocabSubTree

    
def displayLetterSelectionsAndOption(letterSelections, letterOption, vocabTree):
    showWord = False
    if isinstance(vocabTree[letterOption], dict):
        pass # do nothing
    else: # the current selection narrows to a unique word
        showWord = True
    
    if showWord:
        print(letterSelections + letterOption + ' ' + vocabTree[letterOption][0])
    else:
        print(letterSelections + letterOption)
    return
       
def getLetterOptionsAndStartingIndex(vocabTree):
    options = list(vocabTree.keys())
    if '*' in options:
        ii = options.index('*')
    else:
        ii = random.randrange(len(options))
    return ii, options

def enterLetter(key): # pass the current vocabSubTree
    global mnemonic
    global mnemonicIndeces
    global letterSelections
    global bip39VocabTree
    subTree = getSubTree(letterSelections, vocabTree)
    ii, options = getLetterOptionsAndStartingIndex(subTree)
    displayLetterSelectionsAndOption(letterSelections, options[ii], subTree)
    
    if key == Key.up:
        clear_output(wait=True)
        ii += 1
        ii = ii % len(options)
        displayLetterSelectionsAndOption(letterSelections, options[ii], vocabTree)
    if key == Key.down:
        clear_output(wait=True)
        ii -= 1
        ii = ii % len(options)
        displayLetterSelectionsAndOption(letterSelections, options[ii], vocabTree)
    if key == Key.enter:
        # add option to letterSelections
        if isinstance(vocabTree[options[ii]], dict):
            letterSelections += options[ii]
        else: # the current selection narrows to a unique word
            mnemonic = mnemonic + [vocabTree[options[ii]][0]]
            menmonicIndeces = mnemonicIndeces + [vocabTree[options[ii]][1]]
            return False

    if key == Key.esc:
        clear_output(wait=True)
        print('escape')
        return False
    

def showSelectionChoice(letterSelections, subTree):
    options = list(subTree.keys())
    if '*' in options:
        ii = letterOptions.index('*')
    else:
        ii = random.randrange(len(options))
    showWord = False
    if isinstance(subTree[options[ii]], dict):
        pass # do nothing
    else: # the current selection narrows to a unique word
        showWord = True
    
    if showWord:
        print(letterSelections + options[ii] + ' ' + subTree[options[ii]][0])
    else:
        print(letterSelections + options[ii])

    
        

mnemonicLength = 24
mnemonic = []
indeces = []

#while len(mnemonic) < mnemonicLength:
#    selcting = True # entering letters
#    letterSelections = ''
#    while selecting:
#        subTree = getSubTree(letterSelections, bip39VocabTree)
        
#        choice = showSelectionsChoiceAndChoose(letterSelections, subTree)
        
#        isWord, choices = getChoices(subTree)
        



# menu structure
letterSelections = ''
menuItems = {'header': 'Enter Mnemonic Phrase', 'status': 'Word #1', 'options': [letterSelections]}

import random

def updateMenuDisplay(menuItems):
    print(menuItems['header'])
    print(menuItems['status'])
    for option in menuItems['options']:
        print(option)
        



    
def onOption(letterSelections, currentOption, vocabTree):
    isWord, choices = getChoices(letterSelections, currentOption, vocabTree)
    if isWord:
        print(letterSelections + currentOption + ' ' + choices[0])
    else:
        print(letterSelections + currentOption)
    
def onSelection(letterSelections, currentOption, isWord):
    if isWord:
        print('go to confirm')
        return 
    else:
        print('go to select next letter')
        return 

def addLetterToSelections(letterSelections, currentOption):
    return letterSelections + currentOption

def pickCurrentOption(letterSelections):
    return
    
    
        
def getLetterOptions(letterSelections, vocabTree):
    letterOptions = None
    if len(letterSelections) == 0: # first level
        letterOptions = list(vocabTree.keys())
    elif len(letterSelections) == 1: # second level
        letterOptions = list(vocabTree[letterSelections[0]].keys())
    elif len(letterSelections) == 2: # third level
        letterOptions = list(vocabTree[letterSelections[0]][letterSelections[1]].keys())
    elif len(letterSelections) == 3: # fourth level
        letterOptions = list(vocabTree[letterSelections[0]][letterSelections[1]][letterSelections[2]].keys())
    else: # four selections have already been made
        pass
    return letterOptions
    
def getLetterIndexFromOptions(letterOptions):
    if '*' in letterOptions:
        return letterOptions.index('*')
    else:
        return random.randrange(len(letterOptions))
    
def onLetterSelect(letterOptions, letterIndex, letterSelections, vocabTree):
    # if the current display was showing a word, proceed to confirm 
    # otherwise update display with a random letter from the next level displayed
    if len(letterSelections) == 4: # proceed to confirm
        pass
    elif len(letterOptions) == 1: # only one 
        pass
    else: # update menu display to proceed to next letter selection
        pass
    
# def onLetterChange(letterDisplayed, letterSelections, vocabSubTree):
    # if the current letters displayed have only a single word assicated with them, display this word
    # otherwise display just letters
#     if len(vocabSubTree[letterDisplayed].keys()) == 1:        
    
        
        
# a function to handle the mnemonic input UI
# def mnemonicInput(listener, vocabTree, nWords):
    # starting menu items
#    menuItems = {'header': 'Enter Mnemonic Phrase', 'status': 'Word #1', 'options': ['']}

# %%
menomonic =[]
menomonicIndeces = []
letterSelections = ''

#with Listener(on_release = enterLetter) as listener:
#     listener.join()
# non blocking 
listener = Listener(on_release = enterLetter)
listener.start()
# Out:
# This process is not trusted! Input event monitoring will not be possible until it is added to accessibility clients.
# Unhandled exception in listener callback
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/pynput/_util/__init__.py", line 229, in inner
#     return f(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/pynput/_util/darwin.py", line 283, in _handler
#     self._handle(proxy, event_type, event, refcon)
#   File "/opt/anaconda3/lib/python3.11/site-packages/pynput/keyboard/_darwin.py", line 293, in _handle
#     self.on_release(key)
#   File "/opt/anaconda3/lib/python3.11/site-packages/pynput/_util/__init__.py", line 145, in inner
#     if f(*args) is False:
#        ^^^^^^^^
#   File "/var/folders/y3/fylj12tn6837frqz0pb_13zxrdvtf4/T/ipykernel_18671/1716757943.py", line 57, in enterLetter
#     subTree = getSubTree(letterSelections, vocabTree)
#                                            ^^^^^^^^^
# NameError: name 'vocabTree' is not defined

# %%
letterSelections = 'h'
subTree = getSubTree(letterSelections, bip39VocabTree)
showSelectionChoice(letterSelections, subTree)
# Out:
# ha

# %%
getSubTree('assa', bip39VocabTree)
# Out:
# ['assault', 108]

# %%
isWord, choices = getChoices('act', '*', bip39VocabTree)
print(isWord)
# Out:
# True
# ['act', 19]

# %%
onOption('ac', 't', bip39VocabTree)
# Out:
# act

# %%
letOpts = getLetterOptions('zeb', vocabTree)
print(letOpts)
letIdx = getLetterIndexFromOptions(letOpts)
print(letIdx)
# Out:
# ['r']
# 0

# %%
getLetterOptions('wro', vocabTree)
# Out:
# ['n']

# %%
updateMenuDisplay(menuItems)
# Out:
# Enter Mnemonic Phrase
# Word #1

# %%
vocabTree.keys()

# %%
vocabTree['a'].keys()

# %%
vocabTree['a']['g'].keys()

# %%
vocabTree['a']['g']['r']

# %%
ourLetters = []
validLetters = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
currentLetter = 0

ourLetters += [validLetters[currentLetter]]
ourLetters += [validLetters[5]]

print(ourLetters)

# %%
import random
firstLetters = list(vocabTree.keys())
index = random.randint(0, len(firstLetters) - 1)
currentLetter = firstLetters[index]
print(currentLetter)

# %%
firstLetters = list(vocabTree.keys())
index = random.randint(0, len(firstLetters) - 1)
currentLetter = firstLetters[index]
print(currentLetter)
myLetters = '---'
level = 0
possibleLetters = list(vocabTree.keys())


def printLetters(myLetters,level):
    if level >= 2:
        print(myLetters, ' ', vocabTree[myLetters[0]][myLetters[1]][myLetters[2]])
    else:
        print(myLetters)
    return True


# call this function to choose a new word
def word_selection(bip39VocabTree):
    letterSelections = ''
    wordPicked = False
    while not wordPicked:
        subTree = getSubTree(letterSelections, bip39VocabTree)
        showSelectionChoice(letterSelections, subTree)



def on_key_release(key):
    global index
    global myLetters
    global level
    global possibleLetters
    
    if level == 0:
        possibleLetters = list(vocabTree.keys())
    elif level == 1:
        possibleLetters = list(vocabTree[myLetters[0]].keys())
    elif level == 2:
        possibleLetters = list(vocabTree[myLetters[0]][myLetters[1]].keys())
    else:
        return False
    
    if key == Key.up:
        clear_output(wait=True)
        index += 1
        index = index % len(firstLetters)
        print('up pressed')
        print(index)
        
        print(firstLetters[index])
    if key == Key.down:
        clear_output(wait=True)
        index -= 1
        index = index % len(firstLetters)
        print(index)
        print(firstLetters[index])
        print('down pressed')
    if key == Key.enter:
        clear_output(wait=True)
        if level <= 2:
            myLetters[level] = possibleLetters[index]
        
        
        print('enter pressed')
    if key == Key.esc:
        clear_output(wait=True)
        print('escape')
        return False

with Listener(on_release = on_key_release) as listener:
     listener.join()
# non blocking 
# listener = Listener(on_release = on_key_release)
#listener.start()

# %%
import random
